# %% [markdown]
# ### Factorial

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def factorial(n):
    if (n==1 or n==0):
        return 1
    else:
        return n * factorial(n - 1)

# %%
n = int(input())
print("Factorial of "+ str(n) +  " is", factorial(n))
# Out:
# 4
# Factorial of 4 is 24

# %%
# Common method
def factorial(n):
    if n < 0:
        return 0
    elif n == 0 or n == 1:
        return 1
    else:
        fact = 1
        while(n > 1):
            fact *= n
            n -= 1
        return fact
num = 5
print("Factorial of",num,"is",
factorial(num))
# Out:
# Factorial of 5 is 120

# %% [markdown]
# ## Armstrong Number

# %% [markdown]
# Input : 153
# Output : Yes
# 153 is an Armstrong number.
# 1*1*1 + 5*5*5 + 3*3*3 = 153

# %%
num = int(input("Enter a number: "))
sum1 = 0
temp = num
while temp > 0:
    digit = temp % 10
    sum1 += digit ** 3
    temp //= 10

if num == sum1:
    print(num,"is an Armstrong number")
else:
    print(num,"is not an Armstrong number")
# Out:
# Enter a number: 153
# 153 is an Armstrong number

# %% [markdown]
# ## Prime or Not

# %%
num = int(input())

if num > 1:
    for i in range(2, int(num/2)+1):
        if (num % i) == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# 3
# 3 is a prime number

# %% [markdown]
# ### Print all the prime number in given interval

# %%
start = 11
end = 25
 
for i in range(start, end+1):
    if i > 1:
        for j in range(2, i):
            if(i % j == 0):
                break
        else:
            print(i)
# Out:
# 11
# 13
# 17
# 19
# 23

# %% [markdown]
# ### List of all prime numbers

# %% [markdown]
# For checking if a number is prime or not do we really need to iterate through all the number form 2 to n-1? We already know that a number ‘n’ cannot be divided by any number greater than ‘n/2’. So, according to this logic we only need to iterate through 2 to n/2 since number greater than n/2 cannot divide n.

# %%
def isPrime(n):
    if(n==1 or n==0):
        return False   
    for i in range(2,(n//2)+1):
        if(n%i==0):
            return False
    return True 
 
N = 10;
for i in range(1,N+1):
    if(isPrime(i)):
        print(i,end="\n")
# Out:
# 2
# 3
# 5
# 7

# %% [markdown]
# ## Perfect Number

# %%
def isPerfect( n ):
    sum = 1
    i = 2
    while i * i <= n:
        if n % i == 0:
            sum = sum + i + n/i
        i += 1     
    return (True if sum == n and n!=1 else False)
 
for n in range (100):
    if isPerfect (n):
        print(n , " is a perfect number")
# Out:
# 6  is a perfect number
# 28  is a perfect number

# %% [markdown]
# ## Fibonacci

# %%
 def Fibonacci(n):
    if n<= 0:
        print("Incorrect input")
    elif n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return Fibonacci(n-1)+Fibonacci(n-2)
print(Fibonacci(10))
# Out:
# 34

# %%
# different aprroach
def fibonacci(n):
    a = 0
    b = 1
    if n < 0:
        print("Incorrect input")
    elif n == 0:
        return a
    elif n == 1:
        return b
    else:
        for i in range(2, n):
            c = a + b
            a = b
            b = c
        return b 
print(fibonacci(9))
# Out:
# 21
